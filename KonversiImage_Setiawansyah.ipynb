# %% [markdown]
# <a href="https://colab.research.google.com/github/Setiawansyah/Pengenalan-Pola/blob/main/KonversiImage_Setiawansyah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# konversi image
import matplotlib.pyplot as plt
import cv2
babon = cv2.imread("Babon.jpg")
babon_gray = cv2.cvtColor(babon, cv2.COLOR_BGR2GRAY)

plt.imshow(babon) 
plt.imshow(babon_gray)
